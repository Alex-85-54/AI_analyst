# %%
import os
import re
import logging
from langchain.agents import AgentExecutor,  initialize_agent # Tool,
from langchain_core.tools import Tool
from langchain.docstore.document import Document
from langchain.agents.agent_types import AgentType
from langchain_community.vectorstores import FAISS
from langchain_huggingface import HuggingFaceEmbeddings
from langchain_community.document_loaders import TextLoader
from langchain_text_splitters import CharacterTextSplitter, MarkdownHeaderTextSplitter
from langchain_experimental.utilities import PythonREPL
from langchain_openai import ChatOpenAI
import clickhouse_connect

from langchain_huggingface import HuggingFacePipeline
from langchain_huggingface.embeddings import HuggingFaceEndpointEmbeddings
#from langchain_chroma import Chroma

# %%
# Настройка логирования
logger = logging.getLogger()
logger.setLevel(logging.DEBUG)
fh = logging.FileHandler('logs.log')
fh.setFormatter(logging.Formatter('%(asctime)s - %(levelname)s - %(message)s'))
logger.addHandler(fh)
logger.info("START_LOGGING")

# %%
# Конфигурация безопасности
os.environ['AGENT_MODE'] = 'STRICT'  # Запрет управления агентом

# %%
# подключение к БД параметры подключения - в команде запуска контейнера
def connect_to_base(host, port, user, password):
    '''
    Подключение к БД
    '''
    try:
        client = clickhouse_connect.get_client(host= host, port= port, username= user, password= password)
        logger.debug("Connection to the database is successful")
        return client
    except:
        logger.error(f"Error loading to connect: {str(e)}")
        raise HTTPException(status_code=500, detail=f"Error loading the model: {str(e)}")

#client = connect_to_base(os.environ.get(CH_HOST), os.environ.get(CH_PORT), os.environ.get(CH_USER), os.environ.get(CH_PASSWORD))

# %%
# Инструмент 1: Безопасный ClickHouse запрос
def safe_clickhouse_query(query: str) -> str:
    """Выполняет SQL-запросы только для чтения с валидацией"""
    # Защита от инъекций
    forbidden_keywords = ['insert', 'update', 'delete', 'drop', 'alter', 'create', 'grant']
    if any(re.search(rf'\b{kw}\b', query.lower()) for kw in forbidden_keywords):
        return "Ошибка: Запрещенная операция"
    
    # Только SELECT/SHOW/DESCRIBE
    if not re.match(r'^\s*(select|show|describe|with|explain)', query, re.IGNORECASE):
        return "Ошибка: Разрешены только запросы чтения"
    
    try:
        result = client.query(query)
        return str(result.result_rows)
    except Exception as e:
        return f"Ошибка запроса: {str(e)}"

# %%
loader = TextLoader("db_schema_docs.md", encoding="utf-8")

# %%
loader

# %%
documents = loader.load()

# %%
documents[0]
# Out:
# Document(metadata={'source': 'db_schema_docs.md'}, page_content="# Таблица: also_viewed\nОписание: товары, которые смотрели клиенты при покупке\n## **shop_id**: ID магазина (uint32)\n## **client_id**: ID клиента (uint64)\n## **items**: ID Товаров (Float32)\n## **date**: дата (datetime64)\n\n# Таблица: bonus_histories\nОписание: история начисления бонусов\n##  **code**  :    код                   (uint64)       \n##  **shop_id**  :  ID магазина           (uint32)        \n##  **client_id** :  ID клиента           (uint64)        \n##  **status**   :    статус                (string)       \n##  **total_balance** :  итоговый баланс бонусов     (float64)       \n##  **used** :          использовано бонусов   (float64)       \n##   **burned**  :  истек срок годности бонусов     (float64)       \n##  **cancelled** :  отменено банусов            (float64)       \n##  **inactive**  :     неактивно бонусов       (float64)       \n##  **rewarded** :     начисленно бонусов     (float64)       \n##  **purchase_date** :  дата покупки          (datetime64)\n##  **event**  :       событие                (string)        \n##  **order_id**  :     ID покупки            (string)        \n##  **bonus_status** :   статус               (string)        \n##  **amount_changed**:  измененная сумма      (string)        \n## **activated_at**  :  дата активации      (datetime64)\n##  **expiration**  :   дата окончания       (datetime64)\n##  **activity**  :      активность           (string)        \n## **balance**  :       баланс бонусов     (float64)       \n## **date** :    дата создания записи      (datetime64)\n##  **created_at** :   дата + время создания записи     (datetime64)\n\n# Таблица: bounces\nОписание: ---\n##  **shop_id** :        ID магазина               (uint32)       \n##  **source_type**:     тип источника информации  (string)       \n##  **source_id** :      ID источника информации   (uint32)       \n##  **client_id** :       ID клиента               (uint64)       \n##  **code** :            код письма               (string)       \n##   **event**:            событие                 (string)       \n##  **bounce_reason** :   ---                       (string)       \n##  **bounce_action**:    ---                       (string)       \n##  **error_status** :    ---                       (string)       \n##  **diagnostic_code**:  ---                        (string)       \n##  **email** :           email клиента              (string)       \n##  **date** :            дата создания записи     (datetime64)\n##  **created_at**:      дата + время создания записи  (datetime64)\n\n# Таблица: bulk_messages\nОписание: массовые рассылки. Делать анализ вместе с таблицей bulk_messages_hot объединяя их методом UNION\n##   **shop_id** :          ID магазина                        (uint32)       \n##  **bulk_campaign_id**:  ID массовой рассылки                (uint32)       \n##  **client_id** :        ID клиента                          (uint64)       \n##  **code** :             код письма                          (string)       \n##   **event** :            событие, действие над сообщением   (string)       \n##  **channel** : канал, по которому делается рассылка         (string)       \n##  **category** :         ---                                 (string)       \n##  **platform** : тип устройства, с которого пришло событие   (string)       \n##  **uid** :      email адрес!!!!!!!!!!!!                     (string)       \n##  **message_data**:      ---                                 (string)       \n##  **stream**:            ---                                 (string)       \n##  **date**  :            дата создания записи                (datetime64)\n##  **created_at** :       дата + время создания записи        (datetime64)\n##  **location** :         ---                                 (string) \n\n# Таблица: bulk_messages_hot\nОписание: массовые рассылки. Делать анализ вместе с таблицей bulk_messages объединяя их методом UNION\n##  **sho ...

# %%
file_md = open('db_schema_docs.md', encoding='utf-8').read()

# %%
file_md
# Out:
# "# Таблица: also_viewed  Описание: товары, которые смотрели клиенты при покупке\n## **shop_id**: ID магазина (uint32)\n## **client_id**: ID клиента (uint64)\n## **items**: ID Товаров (Float32)\n## **date**: дата (datetime64)\n\n# Таблица: bonus_histories\nОписание: история начисления бонусов\n##  **code**  :    код                   (uint64)       \n##  **shop_id**  :  ID магазина           (uint32)        \n##  **client_id** :  ID клиента           (uint64)        \n##  **status**   :    статус                (string)       \n##  **total_balance** :  итоговый баланс бонусов     (float64)       \n##  **used** :          использовано бонусов   (float64)       \n##   **burned**  :  истек срок годности бонусов     (float64)       \n##  **cancelled** :  отменено банусов            (float64)       \n##  **inactive**  :     неактивно бонусов       (float64)       \n##  **rewarded** :     начисленно бонусов     (float64)       \n##  **purchase_date** :  дата покупки          (datetime64)\n##  **event**  :       событие                (string)        \n##  **order_id**  :     ID покупки            (string)        \n##  **bonus_status** :   статус               (string)        \n##  **amount_changed**:  измененная сумма      (string)        \n## **activated_at**  :  дата активации      (datetime64)\n##  **expiration**  :   дата окончания       (datetime64)\n##  **activity**  :      активность           (string)        \n## **balance**  :       баланс бонусов     (float64)       \n## **date** :    дата создания записи      (datetime64)\n##  **created_at** :   дата + время создания записи     (datetime64)\n\n# Таблица: bounces\nОписание: ---\n##  **shop_id** :        ID магазина               (uint32)       \n##  **source_type**:     тип источника информации  (string)       \n##  **source_id** :      ID источника информации   (uint32)       \n##  **client_id** :       ID клиента               (uint64)       \n##  **code** :            код письма               (string)       \n##   **event**:            событие                 (string)       \n##  **bounce_reason** :   ---                       (string)       \n##  **bounce_action**:    ---                       (string)       \n##  **error_status** :    ---                       (string)       \n##  **diagnostic_code**:  ---                        (string)       \n##  **email** :           email клиента              (string)       \n##  **date** :            дата создания записи     (datetime64)\n##  **created_at**:      дата + время создания записи  (datetime64)\n\n# Таблица: bulk_messages\nОписание: массовые рассылки. Делать анализ вместе с таблицей bulk_messages_hot объединяя их методом UNION\n##   **shop_id** :          ID магазина                        (uint32)       \n##  **bulk_campaign_id**:  ID массовой рассылки                (uint32)       \n##  **client_id** :        ID клиента                          (uint64)       \n##  **code** :             код письма                          (string)       \n##   **event** :            событие, действие над сообщением   (string)       \n##  **channel** : канал, по которому делается рассылка         (string)       \n##  **category** :         ---                                 (string)       \n##  **platform** : тип устройства, с которого пришло событие   (string)       \n##  **uid** :      email адрес!!!!!!!!!!!!                     (string)       \n##  **message_data**:      ---                                 (string)       \n##  **stream**:            ---                                 (string)       \n##  **date**  :            дата создания записи                (datetime64)\n##  **created_at** :       дата + время создания записи        (datetime64)\n##  **location** :         ---                                 (string) \n\n# Таблица: bulk_messages_hot\nОписание: массовые рассылки. Делать анализ вместе с таблицей bulk_messages объединяя их методом UNION\n##  **shop_id** :          ID магазина                        (uint32)    ...

# %%
headers_to_split_on = [
    ("#", "Header 1"),
    ("##", "Header 2"),
]

# %%
text_splitter = MarkdownHeaderTextSplitter(headers_to_split_on=headers_to_split_on)

# %%
def get_chunks(splitter, text):
    chunks = []
    for chunk in splitter.split_text(text):
        # Если chunk - объект Document, используем его page_content
        if hasattr(chunk, 'page_content'):
            page_content = chunk.page_content
            metadata = getattr(chunk, 'metadata', {}).copy()  # Копируем существующие метаданные, если они есть
            metadata.update({"meta": "data"})  # Обновляем их
            chunks.append(Document(page_content=page_content, metadata=metadata))
        else:
            # Если chunk - строка (на всякий случай)
            chunks.append(Document(page_content=chunk, metadata={"meta": "data"}))
    return chunks

# %%
chunks = get_chunks(text_splitter, file_md)

# %%
chunks[0]
# Out:
# Document(metadata={'Header 1': 'Таблица: bonus_histories', 'meta': 'data'}, page_content='Описание: история начисления бонусов')

# %%
FAISS.from_documents(docs, embeddings)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# File c:\AI_agent\v_trade_advisor\lib\site-packages\huggingface_hub\utils\_http.py:409, in hf_raise_for_status(response, endpoint_name)
#     408 try:
# --> 409     response.raise_for_status()
#     410 except HTTPError as e:
#
# File c:\AI_agent\v_trade_advisor\lib\site-packages\requests\models.py:1026, in Response.raise_for_status(self)
#    1025 if http_error_msg:
# -> 1026     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 401 Client Error: Unauthorized for url: https://router.huggingface.co/hf-inference/models/mixedbread-ai/mxbai-embed-large-v1/pipeline/feature-extraction
#
# The above exception was the direct cause of the following exception:
#
# HfHubHTTPError                            Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 FAISS.from_documents(docs, embeddings)
#
# File c:\AI_agent\v_trade_advisor\lib\site-packages\langchain_core\vectorstores\base.py:848, in VectorStore.from_documents(cls, documents, embedding, **kwargs)
#     845     if any(ids):
#     846         kwargs["ids"] = ids
# --> 848 return cls.from_texts(texts, embedding, metadatas=metadatas, **kwargs)
#
# File c:\AI_agent\v_trade_advisor\lib\site-packages\langchain_community\vectorstores\faiss.py:1043, in FAISS.from_texts(cls, texts, embedding, metadatas, ids, **kwargs)
#    1016 @classmethod
#    1017 def from_texts(
#    1018     cls,
#    (...)
#    1023     **kwargs: Any,
#    1024 ) -> FAISS:
#    1025     """Construct FAISS wrapper from raw documents.
#    1026
#    1027     This is a user friendly interface that:
#    (...)
#    1041             faiss = FAISS.from_texts(texts, embeddings)
#    1042     """
# -> 1043     embeddings = embedding.embed_documents(texts)
#    1044     return cls.__from(
#    1045         texts,
#    1046         embeddings,
#    (...)
#    1050         **kwargs,
#    1051     )
#
# File c:\AI_agent\v_trade_advisor\lib\site-packages\langchain_huggingface\embeddings\huggingface_endpoint.py:123, in HuggingFaceEndpointEmbeddings.embed_documents(self, texts)
#     121 _model_kwargs = self.model_kwargs or {}
#     122 #  api doc: https://huggingface.github.io/text-embeddings-inference/#/Text%20Embeddings%20Inference/embed
# --> 123 responses = self.client.feature_extraction(text=texts, **_model_kwargs)
#     124 return responses.tolist()
#
# File c:\AI_agent\v_trade_advisor\lib\site-packages\huggingface_hub\inference\_client.py:1085, in InferenceClient.feature_extraction(self, text, normalize, prompt_name, truncate, truncation_direction, model)
#    1072 provider_helper = get_provider_helper(self.provider, task="feature-extraction", model=model_id)
#    1073 request_parameters = provider_helper.prepare_request(
#    1074     inputs=text,
#    1075     parameters={
#    (...)
#    1083     api_key=self.token,
#    1084 )
# -> 1085 response = self._inner_post(request_parameters)
#    1086 np = _import_numpy()
#    1087 return np.array(provider_helper.get_response(response), dtype="float32")
#
# File c:\AI_agent\v_trade_advisor\lib\site-packages\huggingface_hub\inference\_client.py:278, in InferenceClient._inner_post(self, request_parameters, stream)
#     275         raise InferenceTimeoutError(f"Inference call timed out: {request_parameters.url}") from error  # type: ignore
#     277 try:
# --> 278     hf_raise_for_status(response)
#     279     return response.iter_lines() if stream else response.content
#     280 except HTTPError as error:
#
# File c:\AI_agent\v_trade_advisor\lib\site-packages\huggingface_hub\utils\_http.py:482, in hf_raise_for_status(response, endpoint_name)
#     478     raise _format(HfHubHTTPError, message, response) from e
#     480 # Convert `HTTPError` into a `HfHubHTTPError` to display request information
#     481 # as well (request id and/or server error message)
# --> 482 raise _format(HfHubHTTPError, str(e), response) from e
#
# HfHubHTTPError: 401 Client Error: Unauthorized for url: https://router.huggingface.co/hf-inference/models/mixedbread-ai/mxbai-embed-large-v1/pipeline/feature-extraction

# %%
# Инструмент 2: RAG для схемы базы данных
def setup_rag_agent():
    """Инициализация векторной базы знаний о схеме"""
    loader = TextLoader("db_schema_docs.md", encoding="utf-8")
    documents = loader.load()
    text_splitter = CharacterTextSplitter(chunk_size=1000, chunk_overlap=0)
    docs = text_splitter.split_documents(documents)
    embeddings = HuggingFaceEmbeddings(model_name="cointegrated/LaBSE-en-ru")
    return FAISS.from_documents(docs, embeddings)

vector_db = setup_rag_agent()

def schema_retriever(query: str) -> str:
    """Поиск информации о структуре БД"""
    docs = vector_db.similarity_search(query, k=3)
    return "\n\n".join([d.page_content for d in docs])
# Out:
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# File c:\AI_agent\v_trade_advisor\lib\site-packages\urllib3\connectionpool.py:534, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     533 try:
# --> 534     response = conn.getresponse()
#     535 except (BaseSSLError, OSError) as e:
#
# File c:\AI_agent\v_trade_advisor\lib\site-packages\urllib3\connection.py:565, in HTTPConnection.getresponse(self)
#     564 # Get the response from http.client.HTTPConnection
# --> 565 httplib_response = super().getresponse()
#     567 try:
#
# File ~\AppData\Local\Programs\Python\Python310\lib\http\client.py:1374, in HTTPConnection.getresponse(self)
#    1373 try:
# -> 1374     response.begin()
#    1375 except ConnectionError:
#
# File ~\AppData\Local\Programs\Python\Python310\lib\http\client.py:318, in HTTPResponse.begin(self)
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#
# File ~\AppData\Local\Programs\Python\Python310\lib\http\client.py:279, in HTTPResponse._read_status(self)
#     278 def _read_status(self):
# --> 279     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280     if len(line) > _MAXLINE:
#
# File ~\AppData\Local\Programs\Python\Python310\lib\socket.py:705, in SocketIO.readinto(self, b)
#     704 try:
# --> 705     return self._sock.recv_into(b)
#     706 except timeout:
#
# File ~\AppData\Local\Programs\Python\Python310\lib\ssl.py:1274, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1271         raise ValueError(
#    1272           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1273           self.__class__)
# -> 1274     return self.read(nbytes, buffer)
#    1275 else:
#
# File ~\AppData\Local\Programs\Python\Python310\lib\ssl.py:1130, in SSLSocket.read(self, len, buffer)
#    1129 if buffer is not None:
# -> 1130     return self._sslobj.read(len, buffer)
#    1131 else:
#
# TimeoutError: The read operation timed out
#
# The above exception was the direct cause of the following exception:
#
# ReadTimeoutError                          Traceback (most recent call last)
# File c:\AI_agent\v_trade_advisor\lib\site-packages\requests\adapters.py:667, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     666 try:
# --> 667     resp = conn.urlopen(
#     668         method=request.method,
#     669         url=url,
#     670         body=request.body,
#     671         headers=request.headers,
#     672         redirect=False,
#     673         assert_same_host=False,
#     674         preload_content=False,
#     675         decode_content=False,
#     676         retries=self.max_retries,
#     677         timeout=timeout,
#     678         chunked=chunked,
#     679     )
#     681 except (ProtocolError, OSError) as err:
#
# File c:\AI_agent\v_trade_advisor\lib\site-packages\urllib3\connectionpool.py:841, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     839     new_e = ProtocolError("Connection aborted.", new_e)
# --> 841 retries = retries.increment(
#     842     method, url, error=new_e, _pool=self, _stacktrace=sys.exc_info()[2]
#     843 )
#     844 retries.sleep()
#
# File c:\AI_agent\v_trade_advisor\lib\site-packages\urllib3\util\retry.py:474, in Retry.increment(self, method, url, response, error, _pool, _stacktrace)
#     473 if read is False or method is None or not self._is_method_retryable(method):
# --> 474     raise reraise(type(error), error, _stacktrace)
#     475 elif read is not None:
#
# File c:\AI_agent\v_trade_advisor\lib\site-packages\urllib3\util\util.py:39, in reraise(tp, value, tb)
#      38         raise value.with_traceback(tb)
# ---> 39     raise value
#      40 finally:
#
# File c:\AI_agent\v_trade_advisor\lib\site-packages\urllib3\connectionpool.py:787, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     786 # Make the request on the HTTPConnection object
# --> 787 response = self._make_request(
#     788     conn,
#     789     method,
#     790     url,
#     791     timeout=timeout_obj,
#     792     body=body,
#     793     headers=headers,
#     794     chunked=chunked,
#     795     retries=retries,
#     796     response_conn=response_conn,
#     797     preload_content=preload_content,
#     798     decode_content=decode_content,
#     799     **response_kw,
#     800 )
#     802 # Everything went great!
#
# File c:\AI_agent\v_trade_advisor\lib\site-packages\urllib3\connectionpool.py:536, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     535 except (BaseSSLError, OSError) as e:
# --> 536     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#     537     raise
#
# File c:\AI_agent\v_trade_advisor\lib\site-packages\urllib3\connectionpool.py:367, in HTTPConnectionPool._raise_timeout(self, err, url, timeout_value)
#     366 if isinstance(err, SocketTimeout):
# --> 367     raise ReadTimeoutError(
#     368         self, url, f"Read timed out. (read timeout={timeout_value})"
#     369     ) from err
#     371 # See the above comment about EAGAIN in Python 3.
#
# ReadTimeoutError: HTTPSConnectionPool(host='cdn-lfs.hf.co', port=443): Read timed out. (read timeout=10)
#
# During handling of the above exception, another exception occurred:
#
# ReadTimeout                               Traceback (most recent call last)
# Cell In[15], line 11
#       8     embeddings = HuggingFaceEmbeddings(model_name="cointegrated/LaBSE-en-ru")
#       9     return FAISS.from_documents(docs, embeddings)
# ---> 11 vector_db = setup_rag_agent()
#      13 def schema_retriever(query: str) -> str:
#      14     """Поиск информации о структуре БД"""
#
# Cell In[15], line 8, in setup_rag_agent()
#       6 text_splitter = CharacterTextSplitter(chunk_size=1000, chunk_overlap=0)
#       7 docs = text_splitter.split_documents(documents)
# ----> 8 embeddings = HuggingFaceEmbeddings(model_name="cointegrated/LaBSE-en-ru")
#       9 return FAISS.from_documents(docs, embeddings)
#
# File c:\AI_agent\v_trade_advisor\lib\site-packages\langchain_huggingface\embeddings\huggingface.py:98, in HuggingFaceEmbeddings.__init__(self, **kwargs)
#      95 else:
#      96     model_cls = sentence_transformers.SentenceTransformer
# ---> 98 self._client = model_cls(
#      99     self.model_name, cache_folder=self.cache_folder, **self.model_kwargs
#     100 )
#
# File c:\AI_agent\v_trade_advisor\lib\site-packages\sentence_transformers\SentenceTransformer.py:327, in SentenceTransformer.__init__(self, model_name_or_path, modules, device, prompts, default_prompt_name, similarity_fn_name, cache_folder, trust_remote_code, revision, local_files_only, token, use_auth_token, truncate_dim, model_kwargs, tokenizer_kwargs, config_kwargs, model_card_data, backend)
#     309 has_modules = is_sentence_transformer_model(
#     310     model_name_or_path,
#     311     token,
#    (...)
#     314     local_files_only=local_files_only,
#     315 )
#     316 if (
#     317     has_modules
#     318     and self._get_model_type(
#    (...)
#     325     == self._model_config["model_type"]
#     326 ):
# --> 327     modules, self.module_kwargs = self._load_sbert_model(
#     328         model_name_or_path,
#     329         token=token,
#     330         cache_folder=cache_folder,
#     331         revision=revision,
#     332         trust_remote_code=trust_remote_code,
#     333         local_files_only=local_files_only,
#     334         model_kwargs=model_kwargs,
#     335         tokenizer_kwargs=tokenizer_kwargs,
#     336         config_kwargs=config_kwargs,
#     337     )
#     338 else:
#     339     modules = self._load_auto_model(
#     340         model_name_or_path,
#     341         token=token,
#    (...)
#     349         has_modules=has_modules,
#     350     )
#
# File c:\AI_agent\v_trade_advisor\lib\site-packages\sentence_transformers\SentenceTransformer.py:2254, in SentenceTransformer._load_sbert_model(self, model_name_or_path, token, cache_folder, revision, trust_remote_code, local_files_only, model_kwargs, tokenizer_kwargs, config_kwargs)
#    2249         module = module_class.load(local_path)
#    2251 else:
#    2252     # Newer modules that support the new loading method are loaded with the new style
#    2253     # i.e. with many keyword arguments that can optionally be used by the modules
# -> 2254     module = module_class.load(
#    2255         model_name_or_path,
#    2256         # Loading-specific keyword arguments
#    2257         subfolder=module_config["path"],
#    2258         token=token,
#    2259         cache_folder=cache_folder,
#    2260         revision=revision,
#    2261         local_files_only=local_files_only,
#    2262         # Module-specific keyword arguments
#    2263         trust_remote_code=trust_remote_code,
#    2264         model_kwargs=model_kwargs,
#    2265         tokenizer_kwargs=tokenizer_kwargs,
#    2266         config_kwargs=config_kwargs,
#    2267         backend=self.backend,
#    2268     )
#    2270 modules[module_config["name"]] = module
#    2271 module_kwargs[module_config["name"]] = module_config.get("kwargs", [])
#
# File c:\AI_agent\v_trade_advisor\lib\site-packages\sentence_transformers\models\Transformer.py:541, in Transformer.load(cls, model_name_or_path, subfolder, token, cache_folder, revision, local_files_only, trust_remote_code, model_kwargs, tokenizer_kwargs, config_kwargs, backend, **kwargs)
#     510 @classmethod
#     511 def load(
#     512     cls,
#    (...)
#     526     **kwargs,
#     527 ) -> Self:
#     528     init_kwargs = cls._load_init_kwargs(
#     529         model_name_or_path=model_name_or_path,
#     530         subfolder=subfolder,
#    (...)
#     539         backend=backend,
#     540     )
# --> 541     return cls(model_name_or_path=model_name_or_path, **init_kwargs)
#
# File c:\AI_agent\v_trade_advisor\lib\site-packages\sentence_transformers\models\Transformer.py:88, in Transformer.__init__(self, model_name_or_path, max_seq_length, model_args, tokenizer_args, config_args, cache_dir, do_lower_case, tokenizer_name_or_path, backend)
#      85     config_args = {}
#      87 config, is_peft_model = self._load_config(model_name_or_path, cache_dir, backend, config_args)
# ---> 88 self._load_model(model_name_or_path, config, cache_dir, backend, is_peft_model, **model_args)
#      90 if max_seq_length is not None and "model_max_length" not in tokenizer_args:
#      91     tokenizer_args["model_max_length"] = max_seq_length
#
# File c:\AI_agent\v_trade_advisor\lib\site-packages\sentence_transformers\models\Transformer.py:186, in Transformer._load_model(self, model_name_or_path, config, cache_dir, backend, is_peft_model, **model_args)
#     184         self._load_mt5_model(model_name_or_path, config, cache_dir, **model_args)
#     185     else:
# --> 186         self.auto_model = AutoModel.from_pretrained(
#     187             model_name_or_path, config=config, cache_dir=cache_dir, **model_args
#     188         )
#     189 elif backend == "onnx":
#     190     self._load_onnx_model(model_name_or_path, config, cache_dir, **model_args)
#
# File c:\AI_agent\v_trade_advisor\lib\site-packages\transformers\models\auto\auto_factory.py:600, in _BaseAutoModelClass.from_pretrained(cls, pretrained_model_name_or_path, *model_args, **kwargs)
#     598     if model_class.config_class == config.sub_configs.get("text_config", None):
#     599         config = config.get_text_config()
# --> 600     return model_class.from_pretrained(
#     601         pretrained_model_name_or_path, *model_args, config=config, **hub_kwargs, **kwargs
#     602     )
#     603 raise ValueError(
#     604     f"Unrecognized configuration class {config.__class__} for this kind of AutoModel: {cls.__name__}.\n"
#     605     f"Model type should be one of {', '.join(c.__name__ for c in cls._model_mapping.keys())}."
#     606 )
#
# File c:\AI_agent\v_trade_advisor\lib\site-packages\transformers\modeling_utils.py:315, in restore_default_torch_dtype.<locals>._wrapper(*args, **kwargs)
#     313 old_dtype = torch.get_default_dtype()
#     314 try:
# --> 315     return func(*args, **kwargs)
#     316 finally:
#     317     torch.set_default_dtype(old_dtype)
#
# File c:\AI_agent\v_trade_advisor\lib\site-packages\transformers\modeling_utils.py:4854, in PreTrainedModel.from_pretrained(cls, pretrained_model_name_or_path, config, cache_dir, ignore_mismatched_sizes, force_download, local_files_only, token, revision, use_safetensors, weights_only, *model_args, **kwargs)
#    4844 if (
#    4845     gguf_file
#    4846     and device_map is not None
#    4847     and ((isinstance(device_map, dict) and "disk" in device_map.values()) or "disk" in device_map)
#    4848 ):
#    4849     raise RuntimeError(
#    4850         "One or more modules is configured to be mapped to disk. Disk offload is not supported for models "
#    4851         "loaded from GGUF files."
#    4852     )
# -> 4854 checkpoint_files, sharded_metadata = _get_resolved_checkpoint_files(
#    4855     pretrained_model_name_or_path=pretrained_model_name_or_path,
#    4856     subfolder=subfolder,
#    4857     variant=variant,
#    4858     gguf_file=gguf_file,
#    4859     from_tf=from_tf,
#    4860     from_flax=from_flax,
#    4861     use_safetensors=use_safetensors,
#    4862     cache_dir=cache_dir,
#    4863     force_download=force_download,
#    4864     proxies=proxies,
#    4865     local_files_only=local_files_only,
#    4866     token=token,
#    4867     user_agent=user_agent,
#    4868     revision=revision,
#    4869     commit_hash=commit_hash,
#    4870     is_remote_code=cls._auto_class is not None,
#    4871     transformers_explicit_filename=transformers_explicit_filename,
#    4872 )
#    4874 is_sharded = sharded_metadata is not None
#    4875 is_quantized = hf_quantizer is not None
#
# File c:\AI_agent\v_trade_advisor\lib\site-packages\transformers\modeling_utils.py:1141, in _get_resolved_checkpoint_files(pretrained_model_name_or_path, subfolder, variant, gguf_file, from_tf, from_flax, use_safetensors, cache_dir, force_download, proxies, local_files_only, token, user_agent, revision, commit_hash, is_remote_code, transformers_explicit_filename)
#    1126 try:
#    1127     # Load from URL or cache if already cached
#    1128     cached_file_kwargs = {
#    1129         "cache_dir": cache_dir,
#    1130         "force_download": force_download,
#    (...)
#    1139         "_commit_hash": commit_hash,
#    1140     }
# -> 1141     resolved_archive_file = cached_file(pretrained_model_name_or_path, filename, **cached_file_kwargs)
#    1143     # Since we set _raise_exceptions_for_missing_entries=False, we don't get an exception but a None
#    1144     # result when internet is up, the repo and revision exist, but the file does not.
#    1145     if resolved_archive_file is None and filename == _add_variant(SAFE_WEIGHTS_NAME, variant):
#    1146         # Maybe the checkpoint is sharded, we try to grab the index name in this case.
#
# File c:\AI_agent\v_trade_advisor\lib\site-packages\transformers\utils\hub.py:318, in cached_file(path_or_repo_id, filename, **kwargs)
#     260 def cached_file(
#     261     path_or_repo_id: Union[str, os.PathLike],
#     262     filename: str,
#     263     **kwargs,
#     264 ) -> Optional[str]:
#     265     """
#     266     Tries to locate a file in a local folder and repo, downloads and cache it if necessary.
#     267
#    (...)
#     316     ```
#     317     """
# --> 318     file = cached_files(path_or_repo_id=path_or_repo_id, filenames=[filename], **kwargs)
#     319     file = file[0] if file is not None else file
#     320     return file
#
# File c:\AI_agent\v_trade_advisor\lib\site-packages\transformers\utils\hub.py:564, in cached_files(path_or_repo_id, filenames, cache_dir, force_download, resume_download, proxies, token, revision, local_files_only, subfolder, repo_type, user_agent, _raise_exceptions_for_gated_repo, _raise_exceptions_for_missing_entries, _raise_exceptions_for_connection_errors, _commit_hash, **deprecated_kwargs)
#     561     # Any other Exception type should now be re-raised, in order to provide helpful error messages and break the execution flow
#     562     # (EntryNotFoundError will be treated outside this block and correctly re-raised if needed)
#     563     elif not isinstance(e, EntryNotFoundError):
# --> 564         raise e
#     566 resolved_files = [
#     567     _get_cache_file_to_return(path_or_repo_id, filename, cache_dir, revision) for filename in full_filenames
#     568 ]
#     569 # If there are any missing file and the flag is active, raise
#
# File c:\AI_agent\v_trade_advisor\lib\site-packages\transformers\utils\hub.py:476, in cached_files(path_or_repo_id, filenames, cache_dir, force_download, resume_download, proxies, token, revision, local_files_only, subfolder, repo_type, user_agent, _raise_exceptions_for_gated_repo, _raise_exceptions_for_missing_entries, _raise_exceptions_for_connection_errors, _commit_hash, **deprecated_kwargs)
#     473 try:
#     474     if len(full_filenames) == 1:
#     475         # This is slightly better for only 1 file
# --> 476         hf_hub_download(
#     477             path_or_repo_id,
#     478             filenames[0],
#     479             subfolder=None if len(subfolder) == 0 else subfolder,
#     480             repo_type=repo_type,
#     481             revision=revision,
#     482             cache_dir=cache_dir,
#     483             user_agent=user_agent,
#     484             force_download=force_download,
#     485             proxies=proxies,
#     486             resume_download=resume_download,
#     487             token=token,
#     488             local_files_only=local_files_only,
#     489         )
#     490     else:
#     491         snapshot_download(
#     492             path_or_repo_id,
#     493             allow_patterns=full_filenames,
#    (...)
#     502             local_files_only=local_files_only,
#     503         )
#
# File c:\AI_agent\v_trade_advisor\lib\site-packages\huggingface_hub\utils\_validators.py:114, in validate_hf_hub_args.<locals>._inner_fn(*args, **kwargs)
#     111 if check_use_auth_token:
#     112     kwargs = smoothly_deprecate_use_auth_token(fn_name=fn.__name__, has_token=has_token, kwargs=kwargs)
# --> 114 return fn(*args, **kwargs)
#
# File c:\AI_agent\v_trade_advisor\lib\site-packages\huggingface_hub\file_download.py:1010, in hf_hub_download(repo_id, filename, subfolder, repo_type, revision, library_name, library_version, cache_dir, local_dir, user_agent, force_download, proxies, etag_timeout, token, local_files_only, headers, endpoint, resume_download, force_filename, local_dir_use_symlinks)
#     990     return _hf_hub_download_to_local_dir(
#     991         # Destination
#     992         local_dir=local_dir,
#    (...)
#    1007         local_files_only=local_files_only,
#    1008     )
#    1009 else:
# -> 1010     return _hf_hub_download_to_cache_dir(
#    1011         # Destination
#    1012         cache_dir=cache_dir,
#    1013         # File info
#    1014         repo_id=repo_id,
#    1015         filename=filename,
#    1016         repo_type=repo_type,
#    1017         revision=revision,
#    1018         # HTTP info
#    1019         endpoint=endpoint,
#    1020         etag_timeout=etag_timeout,
#    1021         headers=hf_headers,
#    1022         proxies=proxies,
#    1023         token=token,
#    1024         # Additional options
#    1025         local_files_only=local_files_only,
#    1026         force_download=force_download,
#    1027     )
#
# File c:\AI_agent\v_trade_advisor\lib\site-packages\huggingface_hub\file_download.py:1171, in _hf_hub_download_to_cache_dir(cache_dir, repo_id, filename, repo_type, revision, endpoint, etag_timeout, headers, proxies, token, local_files_only, force_download)
#    1168 # Local file doesn't exist or etag isn't a match => retrieve file from remote (or cache)
#    1170 with WeakFileLock(lock_path):
# -> 1171     _download_to_tmp_and_move(
#    1172         incomplete_path=Path(blob_path + ".incomplete"),
#    1173         destination_path=Path(blob_path),
#    1174         url_to_download=url_to_download,
#    1175         proxies=proxies,
#    1176         headers=headers,
#    1177         expected_size=expected_size,
#    1178         filename=filename,
#    1179         force_download=force_download,
#    1180         etag=etag,
#    1181         xet_file_data=xet_file_data,
#    1182     )
#    1183     if not os.path.exists(pointer_path):
#    1184         _create_symlink(blob_path, pointer_path, new_blob=True)
#
# File c:\AI_agent\v_trade_advisor\lib\site-packages\huggingface_hub\file_download.py:1738, in _download_to_tmp_and_move(incomplete_path, destination_path, url_to_download, proxies, headers, expected_size, filename, force_download, etag, xet_file_data)
#    1731         if xet_file_data is not None and not constants.HF_HUB_DISABLE_XET:
#    1732             logger.warning(
#    1733                 "Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. "
#    1734                 "Falling back to regular HTTP download. "
#    1735                 "For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`"
#    1736             )
# -> 1738         http_get(
#    1739             url_to_download,
#    1740             f,
#    1741             proxies=proxies,
#    1742             resume_size=resume_size,
#    1743             headers=headers,
#    1744             expected_size=expected_size,
#    1745         )
#    1747 logger.info(f"Download complete. Moving file to {destination_path}")
#    1748 _chmod_and_move(incomplete_path, destination_path)
#
# File c:\AI_agent\v_trade_advisor\lib\site-packages\huggingface_hub\file_download.py:426, in http_get(url, temp_file, proxies, resume_size, headers, expected_size, displayed_filename, _nb_retries, _tqdm_bar)
#     420     else:
#     421         raise ValueError(
#     422             "The file is too large to be downloaded using the regular download method. Use `hf_transfer` or `hf_xet` instead."
#     423             " Try `pip install hf_transfer` or `pip install hf_xet`."
#     424         )
# --> 426 r = _request_wrapper(
#     427     method="GET", url=url, stream=True, proxies=proxies, headers=headers, timeout=constants.HF_HUB_DOWNLOAD_TIMEOUT
#     428 )
#     430 hf_raise_for_status(r)
#     431 total: Optional[int] = _get_file_length_from_http_response(r)
#
# File c:\AI_agent\v_trade_advisor\lib\site-packages\huggingface_hub\file_download.py:309, in _request_wrapper(method, url, follow_relative_redirects, **params)
#     306     return response
#     308 # Perform request and return if status_code is not in the retry list.
# --> 309 response = http_backoff(method=method, url=url, **params, retry_on_exceptions=(), retry_on_status_codes=(429,))
#     310 hf_raise_for_status(response)
#     311 return response
#
# File c:\AI_agent\v_trade_advisor\lib\site-packages\huggingface_hub\utils\_http.py:310, in http_backoff(method, url, max_retries, base_wait_time, max_wait_time, retry_on_exceptions, retry_on_status_codes, **kwargs)
#     307     kwargs["data"].seek(io_obj_initial_pos)
#     309 # Perform request and return if status_code is not in the retry list.
# --> 310 response = session.request(method=method, url=url, **kwargs)
#     311 if response.status_code not in retry_on_status_codes:
#     312     return response
#
# File c:\AI_agent\v_trade_advisor\lib\site-packages\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File c:\AI_agent\v_trade_advisor\lib\site-packages\requests\sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File c:\AI_agent\v_trade_advisor\lib\site-packages\huggingface_hub\utils\_http.py:96, in UniqueRequestIdAdapter.send(self, request, *args, **kwargs)
#      94     logger.debug(f"Send: {_curlify(request)}")
#      95 try:
# ---> 96     return super().send(request, *args, **kwargs)
#      97 except requests.RequestException as e:
#      98     request_id = request.headers.get(X_AMZN_TRACE_ID)
#
# File c:\AI_agent\v_trade_advisor\lib\site-packages\requests\adapters.py:713, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     711     raise SSLError(e, request=request)
#     712 elif isinstance(e, ReadTimeoutError):
# --> 713     raise ReadTimeout(e, request=request)
#     714 elif isinstance(e, _InvalidHeader):
#     715     raise InvalidHeader(e, request=request)
#
# ReadTimeout: (ReadTimeoutError("HTTPSConnectionPool(host='cdn-lfs.hf.co', port=443): Read timed out. (read timeout=10)"), '(Request ID: 6bb759a8-6317-4f11-9117-888f9c1096f0)')

# %%
# Инструмент 3: Python для сложных вычислений
python_repl = PythonREPL()

# %%
# Инициализация инструментов
tools = [
    Tool(
        name="ClickHouse_Query",
        func=safe_clickhouse_query,
        description=(
            "Выполнение SQL-запросов к ClickHouse. Только SELECT/SHOW/DESCRIBE. "
            "Вход: валидный SQL-запрос. Выход: результат таблицы."
        )
    ),
    Tool(
        name="Database_Schema",
        func=schema_retriever,
        description=(
            "Поиск информации о структуре базы данных. "
            "Используй для уточнения имен таблиц и столбцов. "
            "Вход: естественный язык."
        )
    ),
    Tool(
        name="Python_REPL",
        func=python_repl.run,
        description=(
            "Выполнение Python кода для сложных вычислений. "
            "Используй только когда невозможно решить через SQL. "
            "Вход: валидный Python код."
        )
    )
]

# %%
# Системный промпт с ограничениями
system_prompt = f"""
Ты senior data analyst. Правила:
1. Только чтение данных (SELECT/SHOW/DESCRIBE)
2. Запрещены DDL/DML операции
3. Для работы с БД используй инструменты
4. Все ответы на русском
5. Формат вывода: таблица Markdown

Доступные базы:
{schema_retriever("Общее описание схемы")}
"""
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 11
#       1 # Системный промпт с ограничениями
#       2 system_prompt = f"""
#       3 Ты senior data analyst. Правила:
#       4 1. Только чтение данных (SELECT/SHOW/DESCRIBE)
#       5 2. Запрещены DDL/DML операции
#       6 3. Для работы с БД используй инструменты
#       7 4. Все ответы на русском
#       8 5. Формат вывода: таблица Markdown
#       9
#      10 Доступные базы:
# ---> 11 {schema_retriever("Общее описание схемы")}
#      12 """
#
# Cell In[10], line 15, in schema_retriever(query)
#      13 def schema_retriever(query: str) -> str:
#      14     """Поиск информации о структуре БД"""
# ---> 15     docs = vector_db.similarity_search(query, k=3)
#      16     return "\n\n".join([d.page_content for d in docs])
#
# NameError: name 'vector_db' is not defined

# %%
# Инициализация агента
agent = initialize_agent(
    tools=tools,
    llm=ChatOpenAI(api_key="sk-f8b7345eb09247468b17932c9884b04c",
                   base_url="https://api.deepseek.com/v1",
                   model="deepseek-chat",
                   temperature=0),
    agent=AgentType.OPENAI_FUNCTIONS,
    agent_kwargs={
        'system_message': system_prompt,
        'extra_prompt_messages': [
            "Важно: Все SQL-запросы проверяй через Database_Schema!",
            "Ограничение: Максимум 5 строк в Python_REPL"
        ]
    },
    verbose=True,
    handle_parsing_errors=True
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 10
#       1 # Инициализация агента
#       2 agent = initialize_agent(
#       3     tools=tools,
#       4     llm=ChatOpenAI(api_key="sk-f8b7345eb09247468b17932c9884b04c",
#       5                    base_url="https://api.deepseek.com/v1",
#       6                    model="deepseek-chat",
#       7                    temperature=0),
#       8     agent=AgentType.OPENAI_FUNCTIONS,
#       9     agent_kwargs={
# ---> 10         'system_message': system_prompt,
#      11         'extra_prompt_messages': [
#      12             "Важно: Все SQL-запросы проверяй через Database_Schema!",
#      13             "Ограничение: Максимум 5 строк в Python_REPL"
#      14         ]
#      15     },
#      16     verbose=True,
#      17     handle_parsing_errors=True
#      18 )
#
# NameError: name 'system_prompt' is not defined

# %%
# Пример использования
if __name__ == "__main__":
    query = "Выгрузи средний чек по месяцам для магазина с id=123 за 2024 год"
    result = agent.invoke({"input": query})
    print(f"\nРезультат:\n{result['output']}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 4
#       2 if __name__ == "__main__":
#       3     query = "Выгрузи средний чек по месяцам для магазина с id=123 за 2024 год"
# ----> 4     result = agent.invoke({"input": query})
#       5     print(f"\nРезультат:\n{result['output']}")
#
# NameError: name 'agent' is not defined
